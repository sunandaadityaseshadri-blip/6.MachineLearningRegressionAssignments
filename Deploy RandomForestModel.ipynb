# %%
import pickle

# %%
loaded_model = pickle.load(open("finalized_model_random_Forest.sav",'rb'))
result = loaded_model.predict([[18,36.85,0,0,1]])

# %%
result
# Out:
# array([55068.205535])
